# %%
from chemcrow.tools.quantum.qho_solver import quantum_harmonic_oscillator
from chemcrow.tools.quantum.hf_energy import hartree_fock_energy
from chemcrow.tools.quantum.molecule_visualizer import visualize_molecule
# Out:
# /root/chemcrow_env/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# WARNING:paperscraper.load_dumps: No dump found for biorxiv. Skipping entry.
# WARNING:paperscraper.load_dumps: No dump found for chemrxiv. Skipping entry.
# WARNING:paperscraper.load_dumps: No dump found for medrxiv. Skipping entry.
# WARNING:paperscraper.load_dumps: No dumps found for either biorxiv, medrxiv and chemrxiv. Consider using paperscraper.get_dumps.* to fetch the dumps.

# %%
print(quantum_harmonic_oscillator("1e14, 5"))
# Out:
# {'energy_levels': [5.2699999999999995e-21, 1.581e-20, 2.6349999999999996e-20, 3.689e-20, 4.7429999999999994e-20], 'units': 'Joules'}

# %%
print(hartree_fock_energy("O"))        # water
print(hartree_fock_energy("c1ccccc1")) # benzene
print(hartree_fock_energy("CCO"))      # ethanol
# Out:
# converged SCF energy = -74.9629322701752
# {'HF_energy': -74.9629322701752, 'units': 'Hartree'}
# converged SCF energy = -227.888262617603
# {'HF_energy': -227.888262617603, 'units': 'Hartree'}
# converged SCF energy = -152.120427930381
# {'HF_energy': -152.12042793038057, 'units': 'Hartree'}

# %%
visualize_molecule("c1ccccc1")  # benzene
# Out:
# <div id="3dmolviewer_17734263879180927"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17734263879180927" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
# Methane
visualize_molecule("C")
# Out:
# <div id="3dmolviewer_17734263893606873"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17734263893606873" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
# Ethanol
visualize_molecule("CCO")
# Out:
# <div id="3dmolviewer_17734263901376839"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17734263901376839" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
# Ammonia
visualize_molecule("N")
# Out:
# <div id="3dmolviewer_1773426390821117"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1773426390821117" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
# Glucose (simplified)
visualize_molecule("C(C1C(C(C(C(O1)O)O)O)O)O")
# Out:
# <div id="3dmolviewer_1773426391318549"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_1773426391318549" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
# Aspirin
visualize_molecule("CC(=O)OC1=CC=CC=C1C(=O)O")
# Out:
# <div id="3dmolviewer_17734263917036889"  style="position: relative; width: 400px; height: 400px;">
#         <p id="3dmolwarning_17734263917036889" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...
